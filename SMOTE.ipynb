# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE

# %%
X, y = make_classification(n_samples=1000, n_redundant=0, n_features=2, n_clusters_per_class=1,
                           weights=[0.90], random_state=29)

# %%
df1 = pd.DataFrame(X, columns=['feature_1', 'feature_2'])
df2 = pd.DataFrame(y, columns=['target'])
df = pd.concat([df1, df2], axis=1)
df.head()
# Out:
#    feature_1  feature_2  target
# 0   1.059651   2.773687       1
# 1   0.710295  -0.845427       0
# 2   0.934230  -1.351191       0
# 3   0.795140  -0.597119       0
# 4   0.475323   0.586381       0

# %%
df['target'].value_counts()
# Out:
# target
# 0    895
# 1    105
# Name: count, dtype: int64

# %%
plt.scatter(df['feature_1'], df['feature_2'], c=df['target'])

# %%
#transform the dataset
oversample = SMOTE()
X, y = oversample.fit_resample(df[['feature_1', 'feature_2']], df['target'])

# %%
X.shape
# Out:
# (1790, 2)

# %%
df1 = pd.DataFrame(X, columns=['feature_1', 'feature_2'])
df2 = pd.DataFrame(y, columns=['target'])
df = pd.concat([df1, df2], axis=1)
df.head()
# Out:
#    feature_1  feature_2  target
# 0   1.059651   2.773687       1
# 1   0.710295  -0.845427       0
# 2   0.934230  -1.351191       0
# 3   0.795140  -0.597119       0
# 4   0.475323   0.586381       0

# %%
plt.scatter(df['feature_1'], df['feature_2'], c=df['target'])
